# %% [markdown]
# # 1.Prepare section

# %% [markdown]
# # 2. Transform section

# %% [markdown]
# # 3. Dataset section

# %% [markdown]
# # 4. Model section

# %% [markdown]
# # 5. Main function section

# %% [markdown]
# # 6. Train section

# %% [markdown]
# # 7. Validation section

# %% [markdown]
# # 8. Test section
